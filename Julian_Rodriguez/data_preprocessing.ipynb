# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from pathlib import Path
PATH = Path('/content/gdrive/My Drive/REU Materials/Data')

# %%
big5 = pd.read_csv(PATH/'data-final.csv', sep = '\t', engine = 'python')

# %%
big5.shape
# Out:
# (1015341, 110)

# %%
big5.head()
# Out:
#    EXT1  EXT2  EXT3  ...  country  lat_appx_lots_of_err  long_appx_lots_of_err
# 0   4.0   1.0   5.0  ...       GB               51.5448                 0.1991
# 1   3.0   5.0   3.0  ...       MY                3.1698                101.706
# 2   2.0   3.0   4.0  ...       GB               54.9119                -1.3833
# 3   2.0   2.0   2.0  ...       GB                 51.75                  -1.25
# 4   3.0   3.0   3.0  ...       KE                   1.0                   38.0
#
# [5 rows x 110 columns]

# %%
#big5.describe()

# %%
#select only responses
big5_data = big5.iloc[:, :50]

# %%
big5_data.shape
# Out:
# (1015341, 50)

# %%
big5_data.head()
# Out:
#    EXT1  EXT2  EXT3  EXT4  EXT5  EXT6  ...  OPN5  OPN6  OPN7  OPN8  OPN9  OPN10
# 0   4.0   1.0   5.0   2.0   5.0   1.0  ...   4.0   1.0   5.0   3.0   4.0    5.0
# 1   3.0   5.0   3.0   4.0   3.0   3.0  ...   3.0   1.0   4.0   2.0   5.0    3.0
# 2   2.0   3.0   4.0   4.0   3.0   2.0  ...   4.0   2.0   5.0   3.0   4.0    4.0
# 3   2.0   2.0   2.0   3.0   4.0   2.0  ...   3.0   1.0   4.0   4.0   3.0    3.0
# 4   3.0   3.0   3.0   3.0   5.0   3.0  ...   5.0   1.0   5.0   3.0   5.0    5.0
#
# [5 rows x 50 columns]

# %%
big5_data.isna().sum().sum()
# Out:
# 89150

# %%
big5_clean = big5_data.dropna()

# %%
cols = big5_clean.columns.values
cols
# Out:
# array(['EXT1', 'EXT2', 'EXT3', 'EXT4', 'EXT5', 'EXT6', 'EXT7', 'EXT8',
#        'EXT9', 'EXT10', 'EST1', 'EST2', 'EST3', 'EST4', 'EST5', 'EST6',
#        'EST7', 'EST8', 'EST9', 'EST10', 'AGR1', 'AGR2', 'AGR3', 'AGR4',
#        'AGR5', 'AGR6', 'AGR7', 'AGR8', 'AGR9', 'AGR10', 'CSN1', 'CSN2',
#        'CSN3', 'CSN4', 'CSN5', 'CSN6', 'CSN7', 'CSN8', 'CSN9', 'CSN10',
#        'OPN1', 'OPN2', 'OPN3', 'OPN4', 'OPN5', 'OPN6', 'OPN7', 'OPN8',
#        'OPN9', 'OPN10'], dtype=object)

# %%
ext_total = big5_clean[cols[:10]].sum(1)
est_total = big5_clean[cols[10:20]].sum(1)
arg_total = big5_clean[cols[20:30]].sum(1)
csn_total = big5_clean[cols[30:40]].sum(1)
opn_total = big5_clean[cols[40:]].sum(1)

# %%
big5_clean.loc[:, 'EXT_total'] = ext_total
big5_clean.loc[:, 'EST_total'] = est_total
big5_clean.loc[:, 'ARG_total'] = arg_total
big5_clean.loc[:, 'CSN_total'] = csn_total
big5_clean.loc[:, 'OPN_total'] = opn_total
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1596: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1781: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item_labels[indexer[info_axis]]] = value

# %%
big5_clean
# Out:
#          EXT1  EXT2  EXT3  EXT4  ...  EST_total  ARG_total  CSN_total  OPN_total
# 0         4.0   1.0   5.0   2.0  ...       24.0       31.0       32.0       33.0
# 1         3.0   5.0   3.0   4.0  ...       21.0       32.0       31.0       27.0
# 2         2.0   3.0   4.0   4.0  ...       26.0       28.0       28.0       31.0
# 3         2.0   2.0   2.0   3.0  ...       27.0       32.0       27.0       31.0
# 4         3.0   3.0   3.0   3.0  ...       23.0       30.0       32.0       36.0
# ...       ...   ...   ...   ...  ...        ...        ...        ...        ...
# 1015336   4.0   2.0   4.0   3.0  ...       33.0       36.0       31.0       29.0
# 1015337   4.0   3.0   4.0   3.0  ...       40.0       33.0       28.0       33.0
# 1015338   4.0   2.0   4.0   3.0  ...       27.0       35.0       33.0       36.0
# 1015339   2.0   4.0   3.0   4.0  ...       33.0       31.0       30.0       35.0
# 1015340   4.0   2.0   4.0   2.0  ...       29.0       34.0       28.0       35.0
#
# ...

# %%
sns.histplot(data = big5_clean, x = 'EXT_total')
plt.show()

# %%
sns.histplot(data = big5_clean, x = 'EST_total')
plt.show()

# %%
sns.histplot(data = big5_clean, x = 'ARG_total')
plt.show()

# %%
sns.histplot(data = big5_clean, x = 'CSN_total')
plt.show()

# %%
sns.histplot(data = big5_clean, x = 'OPN_total')
plt.show()

# %%
big5_scaled = (big5_clean.iloc[:, :-5])/ 5

# %%
big5_scaled.head()
# Out:
#    EXT1  EXT2  EXT3  EXT4  EXT5  EXT6  ...  OPN5  OPN6  OPN7  OPN8  OPN9  OPN10
# 0   0.8   0.2   1.0   0.4   1.0   0.2  ...   0.8   0.2   1.0   0.6   0.8    1.0
# 1   0.6   1.0   0.6   0.8   0.6   0.6  ...   0.6   0.2   0.8   0.4   1.0    0.6
# 2   0.4   0.6   0.8   0.8   0.6   0.4  ...   0.8   0.4   1.0   0.6   0.8    0.8
# 3   0.4   0.4   0.4   0.6   0.8   0.4  ...   0.6   0.2   0.8   0.8   0.6    0.6
# 4   0.6   0.6   0.6   0.6   1.0   0.6  ...   1.0   0.2   1.0   0.6   1.0    1.0
#
# [5 rows x 50 columns]

# %%
big5_np = big5_scaled.to_numpy()

# %%
big5_np
# Out:
# array([[0.8, 0.2, 1. , ..., 0.6, 0.8, 1. ],
#        [0.6, 1. , 0.6, ..., 0.4, 1. , 0.6],
#        [0.4, 0.6, 0.8, ..., 0.6, 0.8, 0.8],
#        ...,
#        [0.8, 0.4, 0.8, ..., 1. , 0.8, 1. ],
#        [0.4, 0.8, 0.6, ..., 1. , 1. , 0.6],
#        [0.8, 0.4, 0.8, ..., 0.8, 1. , 1. ]])

# %%
from sklearn.model_selection import train_test_split

# %%
# split data into Training set and Test set (we can do validation set using Keras while training)
X_train, X_test = train_test_split(big5_np, test_size = .3, random_state = 42)

# %%
X_train.shape
# Out:
# (709490, 50)

# %%
X_test.shape
# Out:
# (304068, 50)

# %%
np.savetxt("train.csv", X_train, delimiter = ",")

# %%
np.savetxt("test.csv", X_test, delimiter = ',')
